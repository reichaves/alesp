# %%
import json
import xmltodict
import pandas as pd
import unidecode
from datetime import date

# %%
# Função para retirar acentuação 
def f(str):
    return (unidecode.unidecode(str))

# %% [markdown]
# ## Comissões

# %% [markdown]
# Fonte
# https://www.al.sp.gov.br/dados-abertos/recurso/43

# %%
with open("dados/processo_legislativo/comissoes_julho_2018.xml", 'r') as f:
    xmlString = f.read()
    
jsonString = json.dumps(xmltodict.parse(xmlString), indent=4)

with open("output.json", 'w') as f:
    f.write(jsonString)

# %%
arquivo_json = open('output.json', 'r')
dados_json = json.load(arquivo_json)

# %%
lista = dados_json['Comissoes']['Comissao']

# %%
df_comissoes = pd.DataFrame(lista, columns = ['DataFimComissao', 'IdComissao', 'NomeComissao', 'SiglaComissao'])

# %%
df_comissoes['DataFimComissao'] = pd.to_datetime(df_comissoes['DataFimComissao'])

# %%
df_comissoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 4 columns):
# DataFimComissao    65 non-null datetime64[ns]
# IdComissao         104 non-null object
# NomeComissao       104 non-null object
# SiglaComissao      97 non-null object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 3.3+ KB

# %%
df_comissoes.reset_index().head(10)
# Out:
#    index     DataFimComissao IdComissao  \
# 0      0 2008-06-26 03:00:00      11072
# 1      1 2008-06-25 03:00:00      11073
# 2      2 2009-04-15 03:00:00      11199
# 3      3                 NaT      12769
# 4      4                 NaT      12770
# 5      5 2010-02-03 02:00:00      12216
# 6      6 2010-10-25 02:00:00      12221
# 7      7 2010-10-06 03:00:00      12222
# 8      8 2010-10-25 02:00:00      12223
# 9      9                 NaT      12444
#
#                                         NomeComissao SiglaComissao
# 0                               CPI da Guerra Fiscal         CPIGF
# 1           CPI da Queima da Palha da Cana-de-açúcar       CPIQPCA
# 2                                  CPI da Santa Casa         CPISC
# 3  Comissão Especial de Reforma da Lei Orgânica d...        CERLOM
# 4                  Comissão do Serviço Público Civil          CSPC
# 5                                 CPI do Erro Médico         CPIEM
# 6                                        CPI BANCOOP    CPIBANCOOP
# 7                                           CPI IPVA       CPIIPVA
# 8                                      CPI Pedofilia      CPIPEDOF
# 9        Comissão de Constituição, Justiça e Redação          CCJR

# %% [markdown]
# Seleciona apenas comissões permanentes ou que acabaram a partir de 2015

# %%
mask = (df_comissoes['DataFimComissao'].dt.year >= 2015) | (df_comissoes['DataFimComissao'].isnull())

df_comissoes = df_comissoes[mask]

# %%
df_comissoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65 entries, 3 to 103
# Data columns (total 4 columns):
# DataFimComissao    26 non-null datetime64[ns]
# IdComissao         65 non-null object
# NomeComissao       65 non-null object
# SiglaComissao      58 non-null object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 2.5+ KB

# %%
df_comissoes.reset_index().head(10)
# Out:
#    index DataFimComissao IdComissao  \
# 0      3             NaT      12769
# 1      4             NaT      12770
# 2      9             NaT      12444
# 3     10             NaT      12445
# 4     11             NaT      12446
# 5     12             NaT      12447
# 6     13             NaT      12448
# 7     14             NaT      12449
# 8     15             NaT      12450
# 9     16             NaT      12451
#
#                                         NomeComissao SiglaComissao
# 0  Comissão Especial de Reforma da Lei Orgânica d...        CERLOM
# 1                  Comissão do Serviço Público Civil          CSPC
# 2        Comissão de Constituição, Justiça e Redação          CCJR
# 3     Comissão de Finanças, Orçamento e Planejamento          CFOP
# 4                                  Comissão de Saúde            CS
# 5                     Comissão de Educação e Cultura           CEC
# 6                   Comissão de Assuntos Desportivos           CAD
# 7   Comissão de Assuntos Metropolitanos e Municipais          CAMM
# 8                         Comissão de Infraestrutura            CI
# 9  Comissão de Segurança Pública e Assuntos Penit...         CSPAP

# %%
a = len(df_comissoes['IdComissao'].value_counts())
a
# Out:
# 65

# %% [markdown]
# ## Membros de Comissões

# %% [markdown]
# Fonte: https://www.al.sp.gov.br/dados-abertos/dataset/8

# %%
with open("dados/processo_legislativo/comissoes_membros_julho_2018.xml", 'r') as f:
    xmlString = f.read()
    
jsonString = json.dumps(xmltodict.parse(xmlString), indent=4)

with open("output.json", 'w') as f:
    f.write(jsonString)

# %%
arquivo_json = open('output.json', 'r')
dados_json = json.load(arquivo_json)

# %%
lista = dados_json['ComissoesMembros']['MembroComissao']

# %%
df_membros = pd.DataFrame(lista, columns = ['DataInicio', 'Efetivo', 'IdComissao', 'IdMembro', 'IdPapel', 'NomeMembro', 'Papel', 'SiglaComissao' ])

# %%
df_membros['DataInicio'] = pd.to_datetime(df_membros['DataInicio'])

# %%
df_membros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4420 entries, 0 to 4419
# Data columns (total 8 columns):
# DataInicio       4420 non-null datetime64[ns]
# Efetivo          4420 non-null object
# IdComissao       4420 non-null object
# IdMembro         4420 non-null object
# IdPapel          4420 non-null object
# NomeMembro       4420 non-null object
# Papel            4420 non-null object
# SiglaComissao    4420 non-null object
# dtypes: datetime64[ns](1), object(7)
# memory usage: 276.3+ KB

# %% [markdown]
# Seleciona apenas a partir de 2015

# %%
mask = (df_membros['DataInicio'].dt.year >= 2015) | (df_membros['DataInicio'].isnull())

df_membros = df_membros[mask]

# %%
df_membros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1567 entries, 0 to 4419
# Data columns (total 8 columns):
# DataInicio       1567 non-null datetime64[ns]
# Efetivo          1567 non-null object
# IdComissao       1567 non-null object
# IdMembro         1567 non-null object
# IdPapel          1567 non-null object
# NomeMembro       1567 non-null object
# Papel            1567 non-null object
# SiglaComissao    1567 non-null object
# dtypes: datetime64[ns](1), object(7)
# memory usage: 110.2+ KB

# %%
df_membros.reset_index().head(10)
# Out:
#    index          DataInicio Efetivo  IdComissao IdMembro IdPapel  \
# 0      0 2017-03-10 03:00:00       N  1000000111    12098       5
# 1      1 2017-05-03 03:00:00       S       12447    12098       6
# 2      2 2017-04-03 03:00:00       S       12456    12098       5
# 3      3 2017-04-03 03:00:00       N       12450    12098       5
# 4      4 2017-04-03 03:00:00       S       12453    12098       5
# 5      5 2017-04-03 03:00:00       N       12446    12098       5
# 6      6 2017-02-14 02:00:00       N  1000000071    12098       5
# 7      7 2017-02-14 02:00:00       S  1000000070    12098       5
# 8     11 2015-04-24 03:00:00       N       12448    12098       5
# 9     16 2015-04-28 03:00:00       S       12446    12098       5
#
#          NomeMembro                     Papel SiglaComissao
# 0  Welson Gasparini           Membro Comissão     CPI-Citri
# 1  Welson Gasparini  Vice-presidente Comissão           CEC
# 2  Welson Gasparini           Membro Comissão          CCTI
# 3  Welson Gasparini           Membro Comissão            CI
# 4  Welson Gasparini           Membro Comissão         CMADS
# 5  Welson Gasparini           Membro Comissão            CS
# 6  Welson Gasparini           Membro Comissão      CPI-PSau
# 7  Welson Gasparini           Membro Comissão      CPI-Deng
# 8  Welson Gasparini           Membro Comissão           CAD
# 9  Welson Gasparini           Membro Comissão            CS

# %%
df_membros.to_excel('resultados/membrosdecomissoes.xlsx',sheet_name='Sheet1')

# %%
df_membros.to_csv('resultados/membrosdecomissoes.csv', index=False)

# %%
a = len(df_membros['IdMembro'].value_counts())
a
# Out:
# 110

# %% [markdown]
# Carrega nomes de deputados da atual legislatura

# %%
nomes_deputados_atual_legislatura = pd.read_csv('resultados/deputados_selecionados_final.csv', converters={'sequencial': lambda x: str(x), 'cpf': lambda x: str(x), 'codigo_unico': lambda x: str(x) })

# %%
nomes_deputados_atual_legislatura.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 9 columns):
# codigo_unico       120 non-null object
# nome_deputado      120 non-null object
# uf                 120 non-null object
# nome_completo      120 non-null object
# sequencial         120 non-null object
# cpf                120 non-null object
# nome_urna          120 non-null object
# partido_eleicao    120 non-null object
# situacao           120 non-null object
# dtypes: object(9)
# memory usage: 8.5+ KB

# %%
df_membros_atuais = pd.merge(df_membros, nomes_deputados_atual_legislatura, left_on='IdMembro', right_on='codigo_unico')

# %%
df_membros_atuais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1556 entries, 0 to 1555
# Data columns (total 17 columns):
# DataInicio         1556 non-null datetime64[ns]
# Efetivo            1556 non-null object
# IdComissao         1556 non-null object
# IdMembro           1556 non-null object
# IdPapel            1556 non-null object
# NomeMembro         1556 non-null object
# Papel              1556 non-null object
# SiglaComissao      1556 non-null object
# codigo_unico       1556 non-null object
# nome_deputado      1556 non-null object
# uf                 1556 non-null object
# nome_completo      1556 non-null object
# sequencial         1556 non-null object
# cpf                1556 non-null object
# nome_urna          1556 non-null object
# partido_eleicao    1556 non-null object
# situacao           1556 non-null object
# dtypes: datetime64[ns](1), object(16)
# memory usage: 218.8+ KB

# %%
a = len(df_membros_atuais['IdMembro'].value_counts())
a
# Out:
# 105

# %% [markdown]
# Verifica se há nomes não encontrados

# %%
nomes_naoencontrados = pd.merge(df_membros, 
                        nomes_deputados_atual_legislatura, 
                        left_on='IdMembro', 
                        right_on='codigo_unico',
                        how='outer',
                        indicator=True)

# %%
rdf = nomes_naoencontrados.query("_merge == 'right_only'").drop('_merge',axis=1)

# %%
rdf[['nome_urna','situacao']]
# Out:
#                   nome_urna       situacao
# 1567        EDSON FERRARINI       SUPLENTE
# 1568        GILSON DE SOUZA       SUPLENTE
# 1569         ANTONIO MENTOR       SUPLENTE
# 1570       JOSE BITTENCOURT       SUPLENTE
# 1571           VANESSA DAMO     NÃO ELEITO
# 1572        LUCIANO BATISTA       SUPLENTE
# 1573           BETO TRICOLI       SUPLENTE
# 1574     GERSON BITTENCOURT       SUPLENTE
# 1575         TELMA DE SOUZA       SUPLENTE
# 1576  ALEXANDRE DA FARMACIA       SUPLENTE
# 1577            LEANDRO KLB       SUPLENTE
# 1578       OSVALDO VERGINIO       SUPLENTE
# 1579           SARAH MUNHOZ       SUPLENTE
# 1580        ANGELO PERUGINI  ELEITO POR QP
# 1581          ULISSES SALES       SUPLENTE

# %% [markdown]
# Todos são suplentes e ficaram períodos nos cargos, com exceção de ANGELO PERUGINI e VANESSA DAMO que deixaram a Assembleia. Ele é prefeito do Hortolândia e ela foi cassada por supostamente distribuir panfletos apócrifos na eleição de 2012. No banco de dados do TSE ela aparece como situação NÃO ELEITO

# %% [markdown]
# ## Presença nas Comissões

# %%
with open("dados/processo_legislativo/comissoes_permanentes_presencas_julho_2018.xml", 'r') as f:
    xmlString = f.read()
    
jsonString = json.dumps(xmltodict.parse(xmlString), indent=4)

with open("output.json", 'w') as f:
    f.write(jsonString)

# %%
arquivo_json = open('output.json', 'r')
dados_json = json.load(arquivo_json)

# %%
#dados_json

# %%
lista = dados_json['ComissoesReunioesPresencas']['ReuniaoComissaoPresenca']

# %%
df_presencas = pd.DataFrame(lista, columns = ['DataReuniao', 'IdComissao', 'IdDeputado', 'IdPauta', 'IdReuniao', 'Deputado', 'SiglaComissao' ])

# %%
df_presencas['DataReuniao'] = pd.to_datetime(df_presencas['DataReuniao'])

# %%
df_presencas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18631 entries, 0 to 18630
# Data columns (total 7 columns):
# DataReuniao      18631 non-null datetime64[ns]
# IdComissao       18631 non-null object
# IdDeputado       18631 non-null object
# IdPauta          18631 non-null object
# IdReuniao        18631 non-null object
# Deputado         18631 non-null object
# SiglaComissao    18631 non-null object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 1019.0+ KB

# %%
df_presencas.reset_index().head()
# Out:
#    index         DataReuniao IdComissao IdDeputado IdPauta IdReuniao  \
# 0      0 2005-08-04 03:00:00       8508         54   48938      6197
# 1      1 2005-08-04 03:00:00       8508        425   48938      6197
# 2      2 2005-08-04 03:00:00       8508         97   48938      6197
# 3      3 2005-08-04 03:00:00       8508        459   48938      6197
# 4      4 2005-08-04 03:00:00       8508        418   48938      6197
#
#            Deputado SiglaComissao
# 0    Rosmary Corrêa           CDH
# 1     Italo Cardoso           CDH
# 2  Hamilton Pereira           CDH
# 3       Ana Martins           CDH
# 4      Ana do Carmo           CDH

# %% [markdown]
# Seleciona apenas a partir de 2015

# %%
mask = (df_presencas['DataReuniao'].dt.year >= 2015)

df_presencas = df_presencas[mask]

# %%
df_presencas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6653 entries, 11863 to 18630
# Data columns (total 7 columns):
# DataReuniao      6653 non-null datetime64[ns]
# IdComissao       6653 non-null object
# IdDeputado       6653 non-null object
# IdPauta          6653 non-null object
# IdReuniao        6653 non-null object
# Deputado         6653 non-null object
# SiglaComissao    6653 non-null object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 415.8+ KB

# %% [markdown]
# Deputados mais membros de comissões

# %%
df_comissao_membros = pd.merge(df_comissoes, df_membros_atuais, left_on='IdComissao', right_on='IdComissao')

# %%
a = len(df_comissao_membros['IdMembro'].value_counts())
a
# Out:
# 105

# %% [markdown]
# Conta pelos IdComissao únicos

# %%
df_comissao_membros.groupby('NomeMembro')['IdComissao'].nunique().sort_values(ascending=False)
# Out:
# NomeMembro
# Wellington Moura         24
# Cezinha de Madureira     22
# Beth Sahão               21
# Ed Thomas                21
# Carlão Pignatari         21
# Carlos Cezar             21
# Jooji Hato               20
# Fernando Cury            20
# Marta Costa              19
# Márcio Camargo           18
# Davi Zaia                18
# Adilson Rossi            17
# Geraldo Cruz             17
# Caio França              17
# Jorge Caruso             17
# Milton Vieira            16
# Coronel Camilo           16
# Chico Sardelli           16
# Roberto Massafera        16
# Marco Vinholi            15
# Ana do Carmo             15
# João Caramez             15
# Ricardo Madalena         14
# Professor Auriel         14
# Alencar Santana Braga    14
# José Zico Prado          14
# Afonso Lobato            14
# Welson Gasparini         13
# Antonio Salim Curiati    13
# Márcia Lia               13
#                          ..
# Milton Leite Filho        7
# Mauro Bragato             7
# Campos Machado            7
# Roberto Tripoli           7
# Roque Barbiere            7
# Feliciano Filho           7
# Abelardo Camarinha        6
# Dilador Borges            6
# Enio Tatto                6
# Vaz de Lima               6
# Rita Passos               6
# Ramalho da Construção     6
# Gilmar Gimenes            6
# Pedro Tobias              6
# Junior Aprillanti         6
# Leci Brandão              5
# Airton Garcia             5
# Igor Soares               5
# Gileno Gomes              5
# Carlos Bezerra Jr.        5
# Estevam Galvão            5
# Luiz Carlos Gondim        4
# Raul Marcelo              4
# Carlos Giannazi           4
# Atila Jacomussi           3
# Rafael Silva              3
# Alexandre Pereira         2
# Vitor Sapienza            2
# Gustavo Petta             1
# Cauê Macris               1
# Name: IdComissao, Length: 105, dtype: int64

# %%
df_comissao_membros.to_excel('resultados/deputados_membros_comissoes.xlsx',sheet_name='Sheet1')

# %%
df_comissao_membros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1556 entries, 0 to 1555
# Data columns (total 20 columns):
# DataFimComissao    458 non-null datetime64[ns]
# IdComissao         1556 non-null object
# NomeComissao       1556 non-null object
# SiglaComissao_x    1556 non-null object
# DataInicio         1556 non-null datetime64[ns]
# Efetivo            1556 non-null object
# IdMembro           1556 non-null object
# IdPapel            1556 non-null object
# NomeMembro         1556 non-null object
# Papel              1556 non-null object
# SiglaComissao_y    1556 non-null object
# codigo_unico       1556 non-null object
# nome_deputado      1556 non-null object
# uf                 1556 non-null object
# nome_completo      1556 non-null object
# sequencial         1556 non-null object
# cpf                1556 non-null object
# nome_urna          1556 non-null object
# partido_eleicao    1556 non-null object
# situacao           1556 non-null object
# dtypes: datetime64[ns](2), object(18)
# memory usage: 255.3+ KB

# %%
conta_membros1 = df_comissao_membros.groupby('IdMembro')['IdComissao'].nunique().sort_values(ascending=False)

conta_membros1 = pd.DataFrame({'IdMembro':conta_membros1.index, 'quantidade_comissoes':conta_membros1.values})

# %%
conta_membros1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 2 columns):
# IdMembro                105 non-null object
# quantidade_comissoes    105 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 1.7+ KB

# %%
conta_membros1.to_csv('resultados/contacomiss1.csv', index=False)

# %% [markdown]
# Detalhes de Wellington Moura - que vale para outros

# %% [markdown]
# Em algumas coissões ele aparece mais de uma vez, como na Comissão de Finanças, Orçamento e Planejamento

# %%
nome = df_comissao_membros[(df_comissao_membros['NomeMembro'] == 'Wellington Moura')]
nome['NomeComissao'].value_counts()
# Out:
# Comissão de Finanças, Orçamento e Planejamento                                                            3
# CPI Pátio de Apreensão de Veículos                                                                        3
# CPI Planos de Saúde                                                                                       2
# CPI - Organizações Sociais da Saúde - OS's                                                                2
# Comissão de Saúde                                                                                         2
# Comissão de Assuntos Desportivos                                                                          2
# Comissão de Fiscalização e Controle                                                                       2
# Comissão de Educação e Cultura                                                                            1
# Comissão de Defesa dos Direitos do Consumidor                                                             1
# Comissão de Administração Pública e Relações do Trabalho                                                  1
# Comissão de Defesa dos Direitos da Pessoa Humana, da Cidadania, da Participação e das Questões Sociais    1
# CPI Maus-Tratos contra Animais                                                                            1
# CPI Merenda                                                                                               1
# CPI Crimes Cibernéticos                                                                                   1
# Comissão de Constituição, Justiça e Redação                                                               1
# CPI Fosfoetanolamina                                                                                      1
# CPI Automedicação                                                                                         1
# CPI Santas Casas                                                                                          1
# CPI Epidemia do Crack                                                                                     1
# CPI Diretórios Acadêmicos e Repúblicas de Estudantes                                                      1
# CPI T4F Entretenimento S/A                                                                                1
# CPI Feiras Itinerantes                                                                                    1
# CPI Operação Ethos/Condepe                                                                                1
# CPI Detran                                                                                                1
# Name: NomeComissao, dtype: int64

# %% [markdown]
# Isso ocorre porque ele pode trocar de cargo dentro na comissão

# %%
seleciona = nome[(nome['NomeComissao'] == 'Comissão de Finanças, Orçamento e Planejamento')]
seleciona
# Out:
#     DataFimComissao IdComissao  \
# 112             NaT      12445
# 113             NaT      12445
# 114             NaT      12445
#
#                                        NomeComissao SiglaComissao_x  \
# 112  Comissão de Finanças, Orçamento e Planejamento            CFOP
# 113  Comissão de Finanças, Orçamento e Planejamento            CFOP
# 114  Comissão de Finanças, Orçamento e Planejamento            CFOP
#
#              DataInicio Efetivo IdMembro IdPapel        NomeMembro  \
# 112 2017-04-17 03:00:00       S    13098       6  Wellington Moura
# 113 2017-04-03 03:00:00       S    13098       5  Wellington Moura
# 114 2018-04-25 03:00:00       S    13098       2  Wellington Moura
#
#                         Papel SiglaComissao_y codigo_unico     nome_deputado  \
# 112  Vice-presidente Comissão            CFOP        13098  WELLINGTON MOURA
# 113           Membro Comissão            CFOP        13098  WELLINGTON MOURA
# 114       Presidente Comissão            CFOP        13098  WELLINGTON MOURA
#
#      uf              nome_completo    sequencial          cpf  \
# 112  SP  WELLINGTON DE SOUZA MOURA  250000001600  28624781809
# 113  SP  WELLINGTON DE SOUZA MOURA  250000001600  28624781809
# 114  SP  WELLINGTON DE SOUZA MOURA  250000001600  28624781809
#
#             nome_urna partido_eleicao       situacao
# 112  WELLINGTON MOURA             PRB  ELEITO POR QP
# 113  WELLINGTON MOURA             PRB  ELEITO POR QP
# 114  WELLINGTON MOURA             PRB  ELEITO POR QP

# %% [markdown]
# Ou a data de início de uma comissão tem mais de uma data

# %%
seleciona = nome[(nome['NomeComissao'] == 'CPI Pátio de Apreensão de Veículos')]
seleciona
# Out:
#          DataFimComissao  IdComissao                        NomeComissao  \
# 1274 2017-12-05 02:00:00  1000000138  CPI Pátio de Apreensão de Veículos
# 1275 2017-12-05 02:00:00  1000000138  CPI Pátio de Apreensão de Veículos
# 1276 2017-12-05 02:00:00  1000000138  CPI Pátio de Apreensão de Veículos
#
#      SiglaComissao_x          DataInicio Efetivo IdMembro IdPapel  \
# 1274       CPI-Patio 2017-05-18 03:00:00       N    13098       5
# 1275       CPI-Patio 2017-05-19 03:00:00       S    13098       5
# 1276       CPI-Patio 2017-05-16 03:00:00       N    13098       5
#
#             NomeMembro            Papel SiglaComissao_y codigo_unico  \
# 1274  Wellington Moura  Membro Comissão       CPI-Patio        13098
# 1275  Wellington Moura  Membro Comissão       CPI-Patio        13098
# 1276  Wellington Moura  Membro Comissão       CPI-Patio        13098
#
#          nome_deputado  uf              nome_completo    sequencial  \
# 1274  WELLINGTON MOURA  SP  WELLINGTON DE SOUZA MOURA  250000001600
# 1275  WELLINGTON MOURA  SP  WELLINGTON DE SOUZA MOURA  250000001600
# 1276  WELLINGTON MOURA  SP  WELLINGTON DE SOUZA MOURA  250000001600
#
#               cpf         nome_urna partido_eleicao       situacao
# 1274  28624781809  WELLINGTON MOURA             PRB  ELEITO POR QP
# 1275  28624781809  WELLINGTON MOURA             PRB  ELEITO POR QP
# 1276  28624781809  WELLINGTON MOURA             PRB  ELEITO POR QP

# %% [markdown]
# Deputados mais presentes em comissões

# %%
df_comissoes_presencas = pd.merge(df_presencas, df_comissoes.drop_duplicates('IdComissao'), left_on='IdComissao', right_on='IdComissao')

# %%
df_comissoes_presencas_selecao = pd.merge(df_comissoes_presencas , nomes_deputados_atual_legislatura, 
                                          left_on='IdDeputado', right_on='codigo_unico')

# %%
df_comissoes_presencas_selecao.to_excel('resultados/comissoes_presencas_selecao.xlsx',sheet_name='Sheet1')

# %%
df_comissoes_presencas_selecao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6643 entries, 0 to 6642
# Data columns (total 19 columns):
# DataReuniao        6643 non-null datetime64[ns]
# IdComissao         6643 non-null object
# IdDeputado         6643 non-null object
# IdPauta            6643 non-null object
# IdReuniao          6643 non-null object
# Deputado           6643 non-null object
# SiglaComissao_x    6643 non-null object
# DataFimComissao    0 non-null datetime64[ns]
# NomeComissao       6643 non-null object
# SiglaComissao_y    6643 non-null object
# codigo_unico       6643 non-null object
# nome_deputado      6643 non-null object
# uf                 6643 non-null object
# nome_completo      6643 non-null object
# sequencial         6643 non-null object
# cpf                6643 non-null object
# nome_urna          6643 non-null object
# partido_eleicao    6643 non-null object
# situacao           6643 non-null object
# dtypes: datetime64[ns](2), object(17)
# memory usage: 1.0+ MB

# %% [markdown]
# Número de deputados com presenças

# %%
a = len(df_comissoes_presencas_selecao['IdDeputado'].value_counts())
a
# Out:
# 113

# %% [markdown]
# Aqui há uma diferença - o número de membros é menor

# %%
a = len(df_comissao_membros['IdMembro'].value_counts())
a
# Out:
# 105

# %% [markdown]
# Isso ocorreu porque alguns deputados da legislatura passada e que são suplentes fizeram reuniões ordinárias de período adicional em 2015. Como este caso (https://www.al.sp.gov.br/alesp/comissao-ata/?idAta=7134&comissao=12444&legislatura=17)

# %%
seleciona = df_comissoes_presencas_selecao[(df_comissoes_presencas_selecao['Deputado'] == 'Antonio Mentor')]
seleciona.head()
# Out:
#             DataReuniao IdComissao IdDeputado IdPauta IdReuniao  \
# 985 2015-02-24 03:00:00      12446        290   56552     12556
# 986 2015-02-11 02:00:00      12444        290   56587     12584
# 987 2015-03-04 03:00:00      12444        290   56611     12605
# 988 2015-03-11 03:00:00      12444        290   56635     12627
# 989 2015-02-03 02:00:00       8520        290   56543     12547
#
#            Deputado SiglaComissao_x DataFimComissao  \
# 985  Antonio Mentor              CS             NaT
# 986  Antonio Mentor            CCJR             NaT
# 987  Antonio Mentor            CCJR             NaT
# 988  Antonio Mentor            CCJR             NaT
# 989  Antonio Mentor             CTC             NaT
#
#                                     NomeComissao SiglaComissao_y codigo_unico  \
# 985                            Comissão de Saúde              CS          290
# 986  Comissão de Constituição, Justiça e Redação            CCJR          290
# 987  Comissão de Constituição, Justiça e Redação            CCJR          290
# 988  Comissão de Constituição, Justiça e Redação            CCJR          290
# 989       Comissão de Transportes e Comunicações             CTC          290
#
#       nome_deputado  uf                     nome_completo    sequencial  \
# 985  ANTONIO MENTOR  SP  ANTONIO MENTOR DE MELLO SOBRINHO  250000000513
# 986  ANTONIO MENTOR  SP  ANTONIO MENTOR DE MELLO SOBRINHO  250000000513
# 987  ANTONIO MENTOR  SP  ANTONIO MENTOR DE MELLO SOBRINHO  250000000513
# 988  ANTONIO MENTOR  SP  ANTONIO MENTOR DE MELLO SOBRINHO  250000000513
# 989  ANTONIO MENTOR  SP  ANTONIO MENTOR DE MELLO SOBRINHO  250000000513
#
#              cpf       nome_urna partido_eleicao  situacao
# 985  44548311815  ANTONIO MENTOR              PT  SUPLENTE
# 986  44548311815  ANTONIO MENTOR              PT  SUPLENTE
# 987  44548311815  ANTONIO MENTOR              PT  SUPLENTE
# 988  44548311815  ANTONIO MENTOR              PT  SUPLENTE
# 989  44548311815  ANTONIO MENTOR              PT  SUPLENTE

# %% [markdown]
# (https://www.al.sp.gov.br/alesp/comissao-ata/?idAta=7110&comissao=12444&legislatura=17)

# %%
seleciona = df_comissoes_presencas_selecao[(df_comissoes_presencas_selecao['Deputado'] == 'José Bittencourt')]
seleciona.head()
# Out:
#              DataReuniao IdComissao IdDeputado IdPauta IdReuniao  \
# 5061 2015-03-11 03:00:00      12444        462   56635     12627
# 5062 2015-03-11 03:00:00      12454        462   56650     12640
# 5063 2015-03-11 03:00:00      12454        462   56661     12649
#
#               Deputado SiglaComissao_x DataFimComissao  \
# 5061  José Bittencourt            CCJR             NaT
# 5062  José Bittencourt             CAE             NaT
# 5063  José Bittencourt             CAE             NaT
#
#                                      NomeComissao SiglaComissao_y  \
# 5061  Comissão de Constituição, Justiça e Redação            CCJR
# 5062            Comissão de Atividades Econômicas             CAE
# 5063            Comissão de Atividades Econômicas             CAE
#
#      codigo_unico     nome_deputado  uf              nome_completo  \
# 5061          462  JOSE BITTENCOURT  SP  JOSÉ DOMINGOS BITTENCOURT
# 5062          462  JOSE BITTENCOURT  SP  JOSÉ DOMINGOS BITTENCOURT
# 5063          462  JOSE BITTENCOURT  SP  JOSÉ DOMINGOS BITTENCOURT
#
#         sequencial          cpf         nome_urna partido_eleicao  situacao
# 5061  250000002656  94509182872  JOSE BITTENCOURT             PSD  SUPLENTE
# 5062  250000002656  94509182872  JOSE BITTENCOURT             PSD  SUPLENTE
# 5063  250000002656  94509182872  JOSE BITTENCOURT             PSD  SUPLENTE

# %% [markdown]
# Deputados com mais presenças

# %%
df_comissoes_presencas_selecao['nome_urna'].value_counts()
# Out:
# CELIA LEAO                           218
# ORLANDO BOLCONE                      180
# CEZINHA DE MADUREIRA                 176
# GILMACI SANTOS                       165
# DAVI ZAIA                            163
# CORONEL CAMILO                       150
# ITAMAR BORGES                        145
# WELLINGTON MOURA                     141
# TEONILIO BARBA                       139
# LUIZ TURCO                           134
# ANTONIO SALIM CURIATI                124
# EDSON GIRIBONI                       122
# CARLAO PIGNATARI                     122
# HELIO NISHIMOTO                      122
# JOAO PAULO RILLO                     117
# CARLOS NEDER                         110
# AFONSO LOBATO                        108
# MARCO VINHOLI                        106
# ROBERTO MASSAFERA                    102
# ANA DO CARMO                         102
# CARLOS CEZAR                         101
# MARTA COSTA                           97
# MARCOS ZERBINI                        93
# ROBERTO ENGLER                        92
# JOSE ZICO PRADO                       90
# CHICO SARDELLI                        85
# MARCOS MARTINS                        84
# CORONEL TELHADA                       83
# ROBERTO TRIPOLI                       82
# ROBERTO MORAIS                        79
#                                     ...
# JOOJI HATO                            23
# MARIA LUCIA AMARY                     23
# FERNANDO CAPEZ                        22
# GILMAR GIMENES                        21
# JUNIOR APRILLANTI                     19
# MARCOS DAMASIO                        17
# PEDRO TOBIAS                          16
# LUIZ CARLOS GONDIM                    14
# IGOR SOARES                           13
# CAUE MACRIS                           13
# JORGE WILSON XERIFE DO CONSUMIDOR     11
# CELINO CARDOSO                        11
# ANTONIO MENTOR                        11
# JORGE CARUSO                          11
# ABELARDO CAMARINHA                    10
# FELICIANO FILHO                        8
# AIRTON GARCIA                          6
# ATILA JACOMUSSI                        5
# VITOR SAPIENZA                         5
# ALEXANDRE PEREIRA                      5
# GERSON BITTENCOURT                     4
# DILADOR BORGES                         4
# BETO TRICOLI                           4
# TELMA DE SOUZA                         3
# JOSE BITTENCOURT                       3
# SARAH MUNHOZ                           2
# RAFAEL SILVA                           2
# VANESSA DAMO                           2
# GUSTAVO PETTA                          2
# OSVALDO VERGINIO                       1
# Name: nome_urna, Length: 113, dtype: int64

# %%
df_comissoes_presencas_selecao.reset_index().head(10)
# Out:
#    index         DataReuniao IdComissao IdDeputado IdPauta IdReuniao  \
# 0      0 2015-02-03 02:00:00      12446      12422   56472     12482
# 1      1 2015-02-24 03:00:00      12446      12422   56552     12556
# 2      2 2015-03-03 03:00:00      12446      12422   56618     12611
# 3      3 2015-02-03 02:00:00      12446      12098   56472     12482
# 4      4 2015-05-06 03:00:00      12446      12098   56722     12693
# 5      5 2015-05-12 03:00:00      12446      12098   56754     12720
# 6      6 2015-05-19 03:00:00      12446      12098   56770     12734
# 7      7 2015-05-26 03:00:00      12446      12098   56788     12749
# 8      8 2015-06-23 03:00:00      12446      12098   56889     12839
# 9      9 2015-08-11 03:00:00      12446      12098   56944     12888
#
#            Deputado SiglaComissao_x DataFimComissao       NomeComissao  \
# 0    Telma de Souza              CS             NaT  Comissão de Saúde
# 1    Telma de Souza              CS             NaT  Comissão de Saúde
# 2    Telma de Souza              CS             NaT  Comissão de Saúde
# 3  Welson Gasparini              CS             NaT  Comissão de Saúde
# 4  Welson Gasparini              CS             NaT  Comissão de Saúde
# 5  Welson Gasparini              CS             NaT  Comissão de Saúde
# 6  Welson Gasparini              CS             NaT  Comissão de Saúde
# 7  Welson Gasparini              CS             NaT  Comissão de Saúde
# 8  Welson Gasparini              CS             NaT  Comissão de Saúde
# 9  Welson Gasparini              CS             NaT  Comissão de Saúde
#
#   SiglaComissao_y codigo_unico     nome_deputado  uf  \
# 0              CS        12422    TELMA DE SOUZA  SP
# 1              CS        12422    TELMA DE SOUZA  SP
# 2              CS        12422    TELMA DE SOUZA  SP
# 3              CS        12098  WELSON GASPARINI  SP
# 4              CS        12098  WELSON GASPARINI  SP
# 5              CS        12098  WELSON GASPARINI  SP
# 6              CS        12098  WELSON GASPARINI  SP
# 7              CS        12098  WELSON GASPARINI  SP
# 8              CS        12098  WELSON GASPARINI  SP
# 9              CS        12098  WELSON GASPARINI  SP
#
#                    nome_completo    sequencial          cpf         nome_urna  \
# 0  TELMA SANDRA AUGUSTO DE SOUZA  250000000594  03732630820    TELMA DE SOUZA
# 1  TELMA SANDRA AUGUSTO DE SOUZA  250000000594  03732630820    TELMA DE SOUZA
# 2  TELMA SANDRA AUGUSTO DE SOUZA  250000000594  03732630820    TELMA DE SOUZA
# 3               WELSON GASPARINI  250000001509  07434219815  WELSON GASPARINI
# 4               WELSON GASPARINI  250000001509  07434219815  WELSON GASPARINI
# 5               WELSON GASPARINI  250000001509  07434219815  WELSON GASPARINI
# 6               WELSON GASPARINI  250000001509  07434219815  WELSON GASPARINI
# 7               WELSON GASPARINI  250000001509  07434219815  WELSON GASPARINI
# 8               WELSON GASPARINI  250000001509  07434219815  WELSON GASPARINI
# 9               WELSON GASPARINI  250000001509  07434219815  WELSON GASPARINI
#
#   partido_eleicao       situacao
# 0              PT       SUPLENTE
# 1              PT       SUPLENTE
# 2              PT       SUPLENTE
# 3            PSDB  ELEITO POR QP
# 4            PSDB  ELEITO POR QP
# 5            PSDB  ELEITO POR QP
# 6            PSDB  ELEITO POR QP
# 7            PSDB  ELEITO POR QP
# 8            PSDB  ELEITO POR QP
# 9            PSDB  ELEITO POR QP

# %%
conta_membros2 = df_comissoes_presencas_selecao['IdDeputado'].value_counts()

conta_membros2 = pd.DataFrame({'IdDeputado':conta_membros2.index, 'presencas_comissoes':conta_membros2.values})

# %%
conta_membros2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113 entries, 0 to 112
# Data columns (total 2 columns):
# IdDeputado             113 non-null object
# presencas_comissoes    113 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 1.8+ KB

# %%
conta_membros2.to_csv('resultados/contacomiss2.csv', index=False)

# %%
reune = pd.merge(conta_membros1, conta_membros2, left_on='IdMembro', right_on='IdDeputado')

# %%
reune2 = pd.merge(reune, nomes_deputados_atual_legislatura, 
                                          left_on='IdDeputado', right_on='codigo_unico')

# %%
reune2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105 entries, 0 to 104
# Data columns (total 13 columns):
# IdMembro                105 non-null object
# quantidade_comissoes    105 non-null int64
# IdDeputado              105 non-null object
# presencas_comissoes     105 non-null int64
# codigo_unico            105 non-null object
# nome_deputado           105 non-null object
# uf                      105 non-null object
# nome_completo           105 non-null object
# sequencial              105 non-null object
# cpf                     105 non-null object
# nome_urna               105 non-null object
# partido_eleicao         105 non-null object
# situacao                105 non-null object
# dtypes: int64(2), object(11)
# memory usage: 11.5+ KB

# %%
reune2[['nome_urna','quantidade_comissoes', 'presencas_comissoes']]
# Out:
#                  nome_urna  quantidade_comissoes  presencas_comissoes
# 0         WELLINGTON MOURA                    24                  141
# 1     CEZINHA DE MADUREIRA                    22                  176
# 2         CARLAO PIGNATARI                    21                  122
# 3                ED THOMAS                    21                   74
# 4             CARLOS CEZAR                    21                  101
# 5               BETH SAHAO                    21                   77
# 6               JOOJI HATO                    20                   23
# 7            FERNANDO CURY                    20                   37
# 8              MARTA COSTA                    19                   97
# 9                DAVI ZAIA                    18                  163
# 10          MARCIO CAMARGO                    18                   71
# 11            GERALDO CRUZ                    17                   74
# 12            JORGE CARUSO                    17                   11
# 13             CAIO FRANCA                    17                   75
# 14           ADILSON ROSSI                    17                   60
# 15       ROBERTO MASSAFERA                    16                  102
# 16          CORONEL CAMILO                    16                  150
# 17           MILTON VIEIRA                    16                   47
# 18          CHICO SARDELLI                    16                   85
# 19            JOAO CARAMEZ                    15                   57
# 20            ANA DO CARMO                    15                  102
# 21           MARCO VINHOLI                    15                  106
# 22   ALENCAR SANTANA BRAGA                    14                   54
# 23        RICARDO MADALENA                    14                   58
# 24        PROFESSOR AURIEL                    14                   55
# 25           AFONSO LOBATO                    14                  108
# 26         JOSE ZICO PRADO                    14                   90
# 27          ROBERTO MORAIS                    13                   79
# 28        WELSON GASPARINI                    13                   66
# 29   ANTONIO SALIM CURIATI                    13                  124
# ..                     ...                   ...                  ...
# 75         ORLANDO BOLCONE                     7                  180
# 76          DOUTOR ULYSSES                     7                   43
# 77          ROQUE BARBIERE                     7                   42
# 78           MAURO BRAGATO                     7                   60
# 79         ROBERTO TRIPOLI                     7                   82
# 80         PAULO CORREA JR                     7                   61
# 81          GILMAR GIMENES                     6                   21
# 82       JUNIOR APRILLANTI                     6                   19
# 83          DILADOR BORGES                     6                    4
# 84   RAMALHO DA CONSTRUCAO                     6                   38
# 85      ABELARDO CAMARINHA                     6                   10
# 86             RITA PASSOS                     6                   51
# 87              ENIO TATTO                     6                   72
# 88             VAZ DE LIMA                     6                   78
# 89            PEDRO TOBIAS                     6                   16
# 90           AIRTON GARCIA                     5                    6
# 91      CARLOS BEZERRA JR.                     5                   44
# 92          ESTEVAM GALVAO                     5                   30
# 93             IGOR SOARES                     5                   13
# 94            LECI BRANDAO                     5                   37
# 95            GILENO GOMES                     5                   40
# 96      LUIZ CARLOS GONDIM                     4                   14
# 97            RAUL MARCELO                     4                   25
# 98         CARLOS GIANNAZI                     4                   53
# 99            RAFAEL SILVA                     3                    2
# 100        ATILA JACOMUSSI                     3                    5
# 101         VITOR SAPIENZA                     2                    5
# 102      ALEXANDRE PEREIRA                     2                    5
# 103            CAUE MACRIS                     1                   13
# 104          GUSTAVO PETTA                     1                    2
#
# [105 rows x 3 columns]

# %%
reune2[['nome_urna','quantidade_comissoes', 'presencas_comissoes']].sort_values(by=['presencas_comissoes'],ascending=False)
# Out:
#                              nome_urna  quantidade_comissoes  \
# 43                          CELIA LEAO                    12
# 75                     ORLANDO BOLCONE                     7
# 1                 CEZINHA DE MADUREIRA                    22
# 49                      GILMACI SANTOS                    11
# 9                            DAVI ZAIA                    18
# 16                      CORONEL CAMILO                    16
# 37                       ITAMAR BORGES                    12
# 0                     WELLINGTON MOURA                    24
# 66                      TEONILIO BARBA                     8
# 51                          LUIZ TURCO                    11
# 29               ANTONIO SALIM CURIATI                    13
# 2                     CARLAO PIGNATARI                    21
# 56                      EDSON GIRIBONI                    10
# 41                     HELIO NISHIMOTO                    12
# 45                    JOAO PAULO RILLO                    12
# 63                        CARLOS NEDER                     9
# 25                       AFONSO LOBATO                    14
# 21                       MARCO VINHOLI                    15
# 15                   ROBERTO MASSAFERA                    16
# 20                        ANA DO CARMO                    15
# 4                         CARLOS CEZAR                    21
# 8                          MARTA COSTA                    19
# 65                      MARCOS ZERBINI                     8
# 39                      ROBERTO ENGLER                    12
# 26                     JOSE ZICO PRADO                    14
# 18                      CHICO SARDELLI                    16
# 58                      MARCOS MARTINS                    10
# 35                     CORONEL TELHADA                    12
# 79                     ROBERTO TRIPOLI                     7
# 27                      ROBERTO MORAIS                    13
# ..                                 ...                   ...
# 69                        MARCOS NEVES                     8
# 61                        JOSE AMERICO                     9
# 53                   ANALICE FERNANDES                    10
# 92                      ESTEVAM GALVAO                     5
# 74                      CAMPOS MACHADO                     7
# 71                  MILTON LEITE FILHO                     7
# 97                        RAUL MARCELO                     4
# 70                          PEDRO KAKA                     7
# 42                   MARIA LUCIA AMARY                    12
# 6                           JOOJI HATO                    20
# 72                      FERNANDO CAPEZ                     7
# 81                      GILMAR GIMENES                     6
# 82                   JUNIOR APRILLANTI                     6
# 59                      MARCOS DAMASIO                    10
# 89                        PEDRO TOBIAS                     6
# 96                  LUIZ CARLOS GONDIM                     4
# 93                         IGOR SOARES                     5
# 103                        CAUE MACRIS                     1
# 12                        JORGE CARUSO                    17
# 47   JORGE WILSON XERIFE DO CONSUMIDOR                    11
# 67                      CELINO CARDOSO                     8
# 85                  ABELARDO CAMARINHA                     6
# 73                     FELICIANO FILHO                     7
# 90                       AIRTON GARCIA                     5
# 102                  ALEXANDRE PEREIRA                     2
# 100                    ATILA JACOMUSSI                     3
# 101                     VITOR SAPIENZA                     2
# 83                      DILADOR BORGES                     6
# 99                        RAFAEL SILVA                     3
# 104                      GUSTAVO PETTA                     1
#
#      presencas_comissoes
# 43                   218
# 75                   180
# 1                    176
# 49                   165
# 9                    163
# 16                   150
# 37                   145
# 0                    141
# 66                   139
# 51                   134
# 29                   124
# 2                    122
# 56                   122
# 41                   122
# 45                   117
# 63                   110
# 25                   108
# 21                   106
# 15                   102
# 20                   102
# 4                    101
# 8                     97
# 65                    93
# 39                    92
# 26                    90
# 18                    85
# 58                    84
# 35                    83
# 79                    82
# 27                    79
# ..                   ...
# 69                    33
# 61                    33
# 53                    32
# 92                    30
# 74                    28
# 71                    28
# 97                    25
# 70                    24
# 42                    23
# 6                     23
# 72                    22
# 81                    21
# 82                    19
# 59                    17
# 89                    16
# 96                    14
# 93                    13
# 103                   13
# 12                    11
# 47                    11
# 67                    11
# 85                    10
# 73                     8
# 90                     6
# 102                    5
# 100                    5
# 101                    5
# 83                     4
# 99                     2
# 104                    2
#
# [105 rows x 3 columns]

# %% [markdown]
# Conjunto de maiores despesas de verba de gabinete

# %%
verba_gabinete = reune2[(reune2['nome_urna'] == 'ITAMAR BORGES') |
                        (reune2['nome_urna'] == 'CARLAO PIGNATARI') |
                        (reune2['nome_urna'] == 'CAMPOS MACHADO') |
                        (reune2['nome_urna'] == 'ALENCAR SANTANA BRAGA') |
                        (reune2['nome_urna'] == 'FELICIANO FILHO') |
                        (reune2['nome_urna'] == 'REINALDO ALGUZ') |
                        (reune2['nome_urna'] == 'ROBERTO MASSAFERA') |
                        (reune2['nome_urna'] == 'DAVI ZAIA') |
                        (reune2['nome_urna'] == 'MARTA COSTA') |
                        (reune2['nome_urna'] == 'TEONILIO BARBA') 
                       ]

# %%
verba_gabinete[['nome_urna','quantidade_comissoes', 'presencas_comissoes']].sort_values(by=['presencas_comissoes'],ascending=False)
# Out:
#                 nome_urna  quantidade_comissoes  presencas_comissoes
# 9               DAVI ZAIA                    18                  163
# 37          ITAMAR BORGES                    12                  145
# 66         TEONILIO BARBA                     8                  139
# 2        CARLAO PIGNATARI                    21                  122
# 15      ROBERTO MASSAFERA                    16                  102
# 8             MARTA COSTA                    19                   97
# 22  ALENCAR SANTANA BRAGA                    14                   54
# 54         REINALDO ALGUZ                    10                   45
# 74         CAMPOS MACHADO                     7                   28
# 73        FELICIANO FILHO                     7                    8

# %% [markdown]
# Gastos com pessoal

# %%
gasto_pessoal = reune2[(reune2['nome_urna'] == 'ALDO DEMARCHI') |
                        (reune2['nome_urna'] == 'ANA DO CARMO') |
                        (reune2['nome_urna'] == 'FERNANDO CAPEZ') |
                        (reune2['nome_urna'] == 'EDMIR CHEDID') |
                        (reune2['nome_urna'] == 'LUIZ CARLOS GONDIM') |
                        (reune2['nome_urna'] == 'LUIZ TURCO') |
                        (reune2['nome_urna'] == 'PEDRO TOBIAS') |
                        (reune2['nome_urna'] == 'ROGERIO NOGUEIRA') |
                        (reune2['nome_urna'] == 'RODRIGO MORAES') |
                        (reune2['nome_urna'] == 'RAFAEL SILVA') 
                       ]

# %%
gasto_pessoal[['nome_urna','quantidade_comissoes', 'presencas_comissoes']].sort_values(by=['presencas_comissoes'],ascending=False)
# Out:
#              nome_urna  quantidade_comissoes  presencas_comissoes
# 51          LUIZ TURCO                    11                  134
# 20        ANA DO CARMO                    15                  102
# 48        EDMIR CHEDID                    11                   64
# 57       ALDO DEMARCHI                    10                   59
# 44      RODRIGO MORAES                    12                   46
# 33    ROGERIO NOGUEIRA                    13                   39
# 72      FERNANDO CAPEZ                     7                   22
# 89        PEDRO TOBIAS                     6                   16
# 96  LUIZ CARLOS GONDIM                     4                   14
# 99        RAFAEL SILVA                     3                    2
